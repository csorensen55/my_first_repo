# %% [markdown]
# <a href="https://colab.research.google.com/github/csorensen55/my_first_repo/blob/main/Lecture_062724.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('titanic.csv')

# %%
number_list = [4, 24, 100, 17, 1]

# %%
numbers_array = np.array(number_list)

# %%
print(number_list, numbers_array)
# Out:
# [4, 24, 100, 17, 1] [  4  24 100  17   1]

# %%
type(number_list)
# Out:
# list

# %%
type(numbers_array)
# Out:
# numpy.ndarray

# %%
numbers_array * 3
# Out:
# array([ 12,  72, 300,  51,   3])

# %%
numbers_array
# Out:
# array([  4,  24, 100,  17,   1])

# %%
np.linspace(45, 46, 1)
# Out:
# array([45.])

# %%
np.arange(45,67,12)
# Out:
# array([45, 57])

# %%
np.random.random()
# Out:
# 0.7808139077370276

# %%
np.argmax(numbers_array)
# Out:
# 2

# %%
np.where(numbers_array > 10, 'small', 'big')
# Out:
# array(['big', 'small', 'small', 'small', 'big'], dtype='<U5')

# %%
df['AgeGroup'] = np.where(df['Age'] > 54, 'Old', np.where(df['Age'] > 45, 'Middle Age', 'Young'))

# %%
df.head(50
        )
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...
